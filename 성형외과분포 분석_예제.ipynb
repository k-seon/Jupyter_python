# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
plt.rc('axes', unicode_minus = False)

# %matplotlib inline

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
df = pd.read_csv("Data/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv", low_memory = False)
df.shape
# Out:
# (91335, 39)

# %%
df_plastic = df[df["상호명"].str.contains("성형")]
df_plastic["시도명"].unique()
# Out:
# array(['서울특별시', '광주광역시', '경기도', '부산광역시', '대전광역시', '경상남도', nan, '전라북도',
#        '전라남도', '인천광역시', '대구광역시', '충청북도', '경상북도', '울산광역시', '강원도', '충청남도',
#        '제주특별자치도', '세종특별자치시'], dtype=object)

# %%
df_plastic_city = df_plastic["시도명"].value_counts(normalize = 100) * 100
df_plastic_city
# Out:
# 서울특별시      47.058824
# 경기도        16.985294
# 부산광역시       8.455882
# 대구광역시       5.367647
# 인천광역시       4.338235
# 대전광역시       2.647059
# 경상남도        2.647059
# 광주광역시       2.500000
# 충청북도        1.764706
# 전라북도        1.544118
# 울산광역시       1.470588
# 강원도         1.323529
# 제주특별자치도     1.250000
# 충청남도        1.029412
# 전라남도        0.808824
# 경상북도        0.735294
# 세종특별자치시     0.073529
# Name: 시도명, dtype: float64

# %%
df_plastic_city.plot.barh(figsize=(18,18))

# %%
sns.countplot(data = df_plastic, y="시도명", order = df_plastic["시도명"].value_counts().index)

# %%
import folium

# %%
lat_mean = df_plastic["위도"].mean()
lon_mean = df_plastic["경도"].mean()

# %%
folium_map = folium.Map
# Out:
# folium.folium.Map
